# %%
import cv2 as cv

# %%
img = cv.imread('./index.jpeg',0)
print(img)
# Out:
# [[206 206 206 ... 206 206 206]
#  [206 206 206 ... 206 206 206]
#  [206 206 206 ... 206 206 206]
#  ...
#  [206 206 206 ... 206 206 206]
#  [206 206 206 ... 206 206 206]
#  [206 206 206 ... 206 206 206]]

# %%
import matplotlib.pyplot as plt
plt.imshow(img,cmap='gray')
print(img)
# Out:
# [[206 206 206 ... 206 206 206]
#  [206 206 206 ... 206 206 206]
#  [206 206 206 ... 206 206 206]
#  ...
#  [206 206 206 ... 206 206 206]
#  [206 206 206 ... 206 206 206]
#  [206 206 206 ... 206 206 206]]

# %%
print(img[0,0])
# Out:
# 206

# %%
print(img.shape)
# Out:
# (148, 225)

# %%
print(img[100,100])
# Out:
# 126

# %%
print(img[0,])
# Out:
# [206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206]

# %%
print(img[100,])
# Out:
# [206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 208 207 205 203 203 203 204 205 203 206 210 212 208 201 192 186
#  166 150 132 128 137 146 142 134 141 142 142 142 141 140 139 138 139 139
#  140 140 140 139 138 138 135 133 129 127 126 124 121 118 109 107 100  88
#   79  73  67  62  66  65  64  63  64  66  69  71  69  70  71  73  73  73
#   73  73  74  74  75  75  75  75  75  76  74  74  75  75  76  76  76  76
#   78  77  76  74  74  74  74  75  71  75  80  73  59  69 119 173 211 214
#  203 201 209 196 191 214 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206 206
#  206 206 206 206 206 206 206 206 206]
